# %% [markdown]
# # Map Demo
# ## This page features demonstrations of our mapping application's abilities.
# ### It does not include the tables that are generated via the Flask App

# %%
from map_it import *

# %%
all_zips = pd.read_csv('datasets/us-zip-code-latitude-and-longitude.csv', sep=';')

# %%
sf = all_zips.loc[(all_zips['City'] == "San Francisco") & (all_zips["State"] == "CA"), 'Zip'].values
sf = process_zips(sf)
mapit(sf)
# Out:
#  Done!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
wv = all_zips.loc[(all_zips['City'] == "Ravenswood") & (all_zips["State"] == "WV"), 'Zip'].values
wv = process_zips(wv)
mapit(wv)
# Out:
#  Done!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ok = all_zips.loc[(all_zips['City'] == "Oklahoma City") & (all_zips["State"] == "OK"), 'Zip'].values
ok = process_zips(ok)
mapit(ok)
# Out:
# could not fetch for 73117
# could not fetch for 73141
# could not fetch for 73108
# could not fetch for 73106
# could not fetch for 73129
# could not fetch for 73105
#  Done!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
